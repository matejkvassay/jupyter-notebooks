# %% [markdown]
# ## Y-Finance Python scrapper
# Test of package to download data from Yahoo APIs.

# %%
# !pip install --upgrade yfinance matplotlib pandas lxml
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/53/0e/40387099824c98be22cd7e33a620e9d38b61998b031f0b33f0b9959717d2/yfinance-0.1.45.tar.gz
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/19/7a/60bd79c5d79559150f8bba866dd7d434f0a170312e4d15e8aefa5faba294/matplotlib-3.1.1-cp37-cp37m-manylinux1_x86_64.whl (13.1MB)
#      |████████████████████████████████| 13.1MB 6.4MB/s eta 0:00:01    |██████████▏                     | 4.2MB 6.4MB/s eta 0:00:02
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/7e/ab/ea76361f9d3e732e114adcd801d2820d5319c23d0ac5482fa3b412db217e/pandas-0.25.1-cp37-cp37m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 30.6MB/s eta 0:00:01
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/e7/a8/40115c84414c017e1a293f331709eb7534303d3ccd11ef805ac09b1481e7/lxml-4.4.1-cp37-cp37m-manylinux1_x86_64.whl (5.7MB)
#      |████████████████████████████████| 5.8MB 31.5MB/s eta 0:00:01
# Collecting numpy>=1.15 (from yfinance)
#   Downloading https://files.pythonhosted.org/packages/ba/e0/46e2f0540370f2661b044647fa447fef2ecbcc8f7cdb4329ca2feb03fb23/numpy-1.17.2-cp37-cp37m-manylinux1_x86_64.whl (20.3MB)
#      |████████████████████████████████| 20.3MB 15.3MB/s eta 0:00:01     |██████████████████▊             | 11.9MB 15.3MB/s eta 0:00:01
# Collecting requests>=2.20 (from yfinance)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 17.8MB/s eta 0:00:01
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading https://files.pythonhosted.org/packages/69/e7/e9f1661c28f7b87abfa08cb0e8f51dad2240a9f4f741f02ea839835e6d18/multitasking-0.0.9.tar.gz
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/11/fa/0160cd525c62d7abd076a070ff02b2b94de589f1a9789774f17d7c54058e/pyparsing-2.4.2-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 16.1MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/93/f8/518fb0bb89860eea6ff1b96483fbd9236d5ee991485d0f3eceff1770f654/kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (90kB)
#      |████████████████████████████████| 92kB 18.6MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib) (2.8.0)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pytz>=2017.2 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/87/76/46d697698a143e05f77bec5a526bf4e56a0be61d63425b68f4ba553b51f2/pytz-2019.2-py2.py3-none-any.whl (508kB)
#      |████████████████████████████████| 512kB 23.6MB/s eta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.20->yfinance)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 33.3MB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests>=2.20->yfinance)
#   Downloading https://files.pythonhosted.org/packages/e6/60/247f23a7121ae632d62811ba7f273d0e58972d75e58a94d329d51550a47d/urllib3-1.25.3-py2.py3-none-any.whl (150kB)
#      |████████████████████████████████| 153kB 34.1MB/s eta 0:00:01
# Collecting certifi>=2017.4.17 (from requests>=2.20->yfinance)
#   Downloading https://files.pythonhosted.org/packages/18/b0/8146a4f8dd402f60744fa380bc73ca47303cccf8b9190fd16a827281eac2/certifi-2019.9.11-py2.py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 33.4MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5 (from requests>=2.20->yfinance)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 16.7MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (41.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.45-cp37-none-any.whl size=14651 sha256=daacaf54721bba4074d3eb7dc6ca86d999f885c5cc3b0b62b1dec1df4b8006bc
#   Stored in directory: /root/.cache/pip/wheels/0c/d1/df/aa9a7744a4ac353cc9a1f2c3aaea7c1f457fc49de4286f2d88
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-cp37-none-any.whl size=8368 sha256=ac82fc13c68aa36d8d60e263be113e26c9896b721d04028dc2133be738c98200
#   Stored in directory: /root/.cache/pip/wheels/37/fa/73/d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# Installing collected packages: pytz, numpy, pandas, chardet, urllib3, certifi, idna, requests, multitasking, yfinance, pyparsing, kiwisolver, cycler, matplotlib, lxml
# Successfully installed certifi-2019.9.11 chardet-3.0.4 cycler-0.10.0 idna-2.8 kiwisolver-1.1.0 lxml-4.4.1 matplotlib-3.1.1 multitasking-0.0.9 numpy-1.17.2 pandas-0.25.1 pyparsing-2.4.2 pytz-2019.2 requests-2.22.0 urllib3-1.25.3 yfinance-0.1.45

# %% [markdown]
# https://github.com/ranaroussi/yfinance

# %%
import yfinance as yf
from datetime import date
# %matplotlib inline

# %%
str(date.today())
# Out:
# '2019-09-12'

# %%
data = yf.download("SPY AAPL", start="1950-01-01", end=str(date.today()))
# Out:
# [*********************100%***********************]  2 of 2 downloaded

# %%
data
# Out:
#            Adj Close           Close            High             Low          \
#                 AAPL     SPY    AAPL     SPY    AAPL     SPY    AAPL     SPY
# Date
# 1980-12-12      0.41     NaN    0.51     NaN    0.52     NaN    0.51     NaN
# 1980-12-15      0.39     NaN    0.49     NaN    0.49     NaN    0.49     NaN
# 1980-12-16      0.36     NaN    0.45     NaN    0.45     NaN    0.45     NaN
# 1980-12-17      0.37     NaN    0.46     NaN    0.46     NaN    0.46     NaN
# 1980-12-18      0.38     NaN    0.48     NaN    0.48     NaN    0.48     NaN
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 2019-09-05    213.28  297.82  213.28  297.82  213.97  298.83  211.51  294.00
# 2019-09-06    213.26  298.05  213.26  298.05  214.42  298.76  212.51  297.42
# 2019-09-09    214.17  298.20  214.17  298.20  216.44  299.24  211.07  297.16
# 2019-09-10    216.70  298.13  216.70  298.13  216.78  298.20  211.71  295.97
# 2019-09-11    223.59  300.25  223.59  300.25  223.71  300.34  217.73  297.75
#
#               Open             Volume
#               AAPL     SPY       AAPL         SPY
# Date
# 1980-12-12    0.51     NaN  117258400         NaN
# 1980-12-15    0.49     NaN   43971200         NaN
# 1980-12-16    0.45     NaN   26432000         NaN
# 1980-12-17    0.46     NaN   21610400         NaN
# 1980-12-18    0.48     NaN   18362400         NaN
# ...            ...     ...        ...         ...
# 2019-09-05  212.00  296.79   23913700  83258100.0
# 2019-09-06  214.05  298.17   19362300  49584300.0
# 2019-09-09  214.84  299.14   27309400  51260300.0
# 2019-09-10  213.86  297.36   31777900  57947100.0
# 2019-09-11  218.07  298.47   43590900  67070400.0
#
# [9769 rows x 12 columns]

# %%
ticker=yf.Ticker('AAPL')

# %%
ticker.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'currency': 'USD',
#  'fiftyTwoWeekLowChange': 83.619995,
#  'fiftyTwoWeekLowChangePercent': 0.5888732,
#  'fiftyTwoWeekRange': '142.0 - 233.47',
#  'fiftyTwoWeekHighChange': -7.850006,
#  'fiftyTwoWeekHighChangePercent': -0.03362319,
#  'fiftyTwoWeekLow': 142.0,
#  'fiftyTwoWeekHigh': 233.47,
#  'dividendDate': 1565827200,
#  'earningsTimestamp': 1564531200,
#  'earningsTimestampStart': 1572447540,
#  'earningsTimestampEnd': 1572886800,
#  'trailingAnnualDividendRate': 2.96,
#  'trailingPE': 19.157679,
#  'trailingAnnualDividendYield': 0.013238518,
#  'epsTrailingTwelveMonths': 11.777,
#  'epsForward': 12.77,
#  'sharesOutstanding': 4519179776,
#  'bookValue': 21.286,
#  'fiftyDayAverage': 207.42543,
#  'fiftyDayAverageChange': 18.194565,
#  'fiftyDayAverageChangePercent': 0.08771617,
#  'marketCap': 1019617345536,
#  'shortName': 'Apple Inc.',
#  'twoHundredDayAverage': 196.71733,
#  'twoHundredDayAverageChange': 28.902664,
#  'twoHundredDayAverageChangePercent': 0.14692485,
#  'forwardPE': 17.66797,
#  'priceToBook': 10.599455,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'esgPopulated': False,
#  'tradeable': True,
#  'triggerable': True,
#  'regularMarketPrice': 225.62,
#  'regularMarketTime': 1568299429,
#  'regularMarketChange': 2.0299988,
#  'regularMarketOpen': 224.8,
#  'regularMarketDayHigh': 226.41,
#  'regularMarketDayLow': 223.02,
#  'regularMarketVolume': 12764915,
#  'marketState': 'REGULAR',
#  'priceHint': 2,
#  'market': 'us_market',
#  'exchange': 'NMS',
#  'exchangeDataDelayedBy': 0,
#  'regularMarketChangePercent': 0.9079113,
#  'regularMarketDayRange': '223.02 - 226.41',
#  'regularMarketPreviousClose': 223.59,
#  'bid': 225.81,
#  'ask': 225.83,
#  'bidSize': 8,
#  'askSize': 9,
#  'messageBoardId': 'finmb_24937',
#  'fullExchangeName': 'NasdaqGS',
#  'longName': 'Apple Inc.',
#  'financialCurrency': 'USD',
#  'averageDailyVolume3Month': 25748650,
#  'averageDailyVolume10Day': 26452185,
#  'symbol': 'AAPL'}

# %%
ticker.financials
# Out:
#                                         9/29/2018  9/30/2017  9/24/2016  \
#
# Total Revenue                           265595000  229234000  215639000
# Cost of Revenue                         163756000  141048000  131376000
# Gross Profit                            101839000   88186000   84263000
# Operating Expenses                              -          -          -
# Research Development                     14236000   11581000   10045000
# Selling General and Administrative       16705000   15261000   14194000
# Non Recurring                                 NaN        NaN        NaN
# Others                                        NaN        NaN        NaN
# Total Operating Expenses                194697000  167890000  155615000
# Operating Income or Loss                 70898000   61344000   60024000
# Income from Continuing Operations               -          -          -
# Total Other Income/Expenses Net           2005000    2745000    1348000
# Earnings Before Interest and Taxes       70898000   61344000   60024000
# Interest Expense                         -3240000   -2323000   -1456000
# Income Before Tax                        72903000   64089000   61372000
# Income Tax Expense                       13372000   15738000   15685000
# Minority Interest                             NaN        NaN        NaN
# Net Income From Continuing Ops           59531000   48351000   45687000
# Non-recurring Events                            -          -          -
# Discontinued Operations                       NaN        NaN        NaN
# Extraordinary Items                           NaN        NaN        NaN
# Effect Of Accounting Changes                  NaN        NaN        NaN
# Other Items                                   NaN        NaN        NaN
# Net Income                                      -          -          -
# Net Income                                      -          -          -
# Preferred Stock And Other Adjustments         NaN        NaN        NaN
# Net Income Applicable To Common Shares   59531000   48351000   45687000
#
#                                         9/26/2015
#
# Total Revenue                           233715000
# Cost of Revenue                         140089000
# Gross Profit                             93626000
# Operating Expenses                              -
# Research Development                      8067000
# Selling General and Administrative       14329000
# Non Recurring                                 NaN
# Others                                        NaN
# Total Operating Expenses                162485000
# Operating Income or Loss                 71230000
# Income from Continuing Operations               -
# Total Other Income/Expenses Net           1285000
# Earnings Before Interest and Taxes       71230000
# Interest Expense                          -733000
# Income Before Tax                        72515000
# Income Tax Expense                       19121000
# Minority Interest                             NaN
# Net Income From Continuing Ops           53394000
# Non-recurring Events                            -
# Discontinued Operations                       NaN
# Extraordinary Items                           NaN
# Effect Of Accounting Changes                  NaN
# Other Items                                   NaN
# Net Income                                      -
# Net Income                                      -
# Preferred Stock And Other Adjustments         NaN
# Net Income Applicable To Common Shares   53394000
